# %% [markdown]
# <a href="https://colab.research.google.com/github/Lsyyy623/Case-Competition-Pillar-1-Team-11/blob/main/code/ucla/ucla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
import re
import time
import random
from urllib.parse import urljoin, urldefrag

import requests
import pandas as pd
from bs4 import BeautifulSoup
from bs4.element import Tag

DIRECTORY_URL = "https://www.anderson.ucla.edu/faculty-and-research/faculty-directory"
OUT_CSV = "ucla_anderson_pubs_papers_only.csv"

HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/120.0 Safari/537.36"
    ),
    "Accept-Language": "en-US,en;q=0.9",
}

# 不要的类型
EXCLUDE_KEYWORDS = [
    "working paper", "working papers",
    "book", "books",
    "book chapter", "book chapters",
    "case", "cases",
    "monograph", "edited volume",
]

# “像论文”的判断：有年份 或 forthcoming/in press/accepted
PAPER_LIKE = re.compile(r"(19\d{2}|20\d{2}|forthcoming|in press|accepted)", re.IGNORECASE)
YEAR_RE = re.compile(r"\b(?:19|20)\d{2}\b")

# ✅ 关键：用正则匹配标题（包含 Select Published Papers）
HEADER_PATTERNS = [
    re.compile(r"\barticles\s+published\s+or\s+accepted\b", re.I),
    re.compile(r"\b(select(ed)?\s+)?published\s+papers?\b", re.I),   # Select/Selected Published Papers
    re.compile(r"\bselected\s+publications?\b", re.I),
    re.compile(r"\bpublications?\b", re.I),
    re.compile(r"\bpapers?\b", re.I),
]

def clean(s: str) -> str:
    return re.sub(r"\s+", " ", (s or "")).strip()

def normalize_url(base: str, href: str) -> str:
    if not href:
        return ""
    u = urljoin(base, href.strip())
    u, _ = urldefrag(u)
    return u.replace("http://", "https://")

def make_soup(html: str) -> BeautifulSoup:
    try:
        return BeautifulSoup(html, "lxml")
    except Exception:
        return BeautifulSoup(html, "html.parser")

def make_session() -> requests.Session:
    s = requests.Session()
    s.headers.update(HEADERS)
    return s

def fetch_html(session: requests.Session, url: str) -> str:
    r = session.get(url, timeout=30)
    r.raise_for_status()
    r.encoding = r.apparent_encoding
    return r.text

def extract_year(entry: str) -> str:
    m = YEAR_RE.search(entry)
    return m.group(0) if m else ""

def looks_excluded(entry: str) -> bool:
    low = entry.lower()
    return any(k in low for k in EXCLUDE_KEYWORDS)

# -------------------------
# 1) 目录页抓所有教授 profile 链接
# -------------------------
def collect_profile_links(session: requests.Session):
    html = fetch_html(session, DIRECTORY_URL)
    soup = make_soup(html)

    links = []
    for a in soup.select("a[href]"):
        href = (a.get("href") or "").strip()
        if not href:
            continue
        u = normalize_url(DIRECTORY_URL, href)

        # UCLA Anderson 教授页常见：.../faculty-and-research/<area>/faculty/<slug>
        if ("/faculty-and-research/" in u) and ("/faculty/" in u) and ("/faculty-directory" not in u):
            if u.lower().endswith((".pdf", ".doc", ".docx")):
                continue
            links.append(u)

    # 去重保序
    seen, uniq = set(), []
    for u in links:
        if u not in seen:
            seen.add(u)
            uniq.append(u)
    return uniq

# -------------------------
# 2) 个人页抽取标题 + 条目
# -------------------------
def get_name(soup: BeautifulSoup) -> str:
    h1 = soup.find("h1")
    if h1:
        return clean(h1.get_text(" ", strip=True))
    h2 = soup.find("h2")
    return clean(h2.get_text(" ", strip=True)) if h2 else ""

def is_target_header(title: str) -> bool:
    t = clean(title)
    if not t:
        return False
    # 太短的比如 “About / Media” 不要
    if len(t) < 5:
        return False
    return any(p.search(t) for p in HEADER_PATTERNS)

def collect_entries_under_header(header: Tag):
    """
    从 header 开始抓到下一个 h2/h3/h4 之前。
    同时支持 p/li + 兜底按行拆文本（适配很多不同结构）。
    """
    entries = []

    for el in header.find_all_next():
        if not isinstance(el, Tag):
            continue

        if el.name in ["h2", "h3", "h4"] and el is not header:
            break

        if el.name in ["p", "li"]:
            txt = clean(el.get_text(" ", strip=True))
            if txt:
                entries.append(txt)

    # 兜底：如果没抓到 p/li，就用 block 文本按行切
    if not entries:
        block = []
        for el in header.find_all_next():
            if isinstance(el, Tag) and el.name in ["h2", "h3", "h4"] and el is not header:
                break
            if isinstance(el, Tag) and el.name in ["div", "section"]:
                t = el.get_text("\n", strip=True)
                if t:
                    block.append(t)
        merged = "\n".join(block)
        for line in merged.split("\n"):
            line = clean(line)
            if line:
                entries.append(line)

    # 过滤：像论文 + 排除 working paper/book
    out, seen = [], set()
    for e in entries:
        if looks_excluded(e):
            continue
        if not PAPER_LIKE.search(e):
            continue
        if e not in seen:
            seen.add(e)
            out.append(e)
    return out

def extract_entries_from_profile(session: requests.Session, profile_url: str):
    html = fetch_html(session, profile_url)
    soup = make_soup(html)
    name = get_name(soup)
    scope = soup.find("main") or soup.find("article") or soup.body or soup

    # ✅ 这里不再要求标题“完全等于”，而是用 is_target_header
    headers = []
    for h in scope.find_all(["h2", "h3", "h4"]):
        title = h.get_text(" ", strip=True)
        if is_target_header(title):
            headers.append(h)

    all_entries = []
    for h in headers:
        all_entries.extend(collect_entries_under_header(h))

    # 去重
    final, seen = [], set()
    for e in all_entries:
        if e not in seen:
            seen.add(e)
            final.append(e)

    return name, final, [clean(h.get_text(" ", strip=True)) for h in headers]

# -------------------------
# main
# -------------------------
def main():
    session = make_session()

    print("Fetching directory:", DIRECTORY_URL)
    profile_links = collect_profile_links(session)
    print(f"Found {len(profile_links)} profile links.")

    rows = []
    for i, url in enumerate(profile_links, 1):
        try:
            time.sleep(random.uniform(0.4, 0.9))
            name, entries, matched_headers = extract_entries_from_profile(session, url)

            if not entries:
                # 如果你想调试，可以把 matched_headers 打印出来看看这个教授页有哪些标题
                print(f"[{i}/{len(profile_links)}] {name or '(no name)'} -> no entries (matched headers={matched_headers[:3]})")
                continue

            print(f"[{i}/{len(profile_links)}] {name} -> {len(entries)} entries")

            for e in entries:
                rows.append({
                    "name": name,
                    "profile_link": url,
                    "entry": e,
                    "year": extract_year(e),
                })

        except Exception as ex:
            print(f"[{i}/{len(profile_links)}] ERROR on {url}: {type(ex).__name__}: {ex}")

    df = pd.DataFrame(rows, columns=["name", "profile_link", "entry", "year"])
    df.to_csv(OUT_CSV, index=False, encoding="utf-8-sig")
    print(f"\nSaved: {OUT_CSV} (rows={len(df)})")

if __name__ == "__main__":
    main()
# Out:
# Fetching directory: https://www.anderson.ucla.edu/faculty-and-research/faculty-directory
# Found 126 profile links.
# [1/126] Derek Alderton -> no entries (matched headers=[])
# [2/126] Corinne Bendersky -> 16 entries
# [3/126] Daniel J. Benjamin -> 21 entries
# [4/126] Tamara Berges -> no entries (matched headers=[])
# [5/126] Antonio Bernardo -> 4 entries
# [6/126] Anand V. Bodapati -> 5 entries
# [7/126] Clement Bohr -> 14 entries
# [8/126] Casey Borman -> no entries (matched headers=[])
# [9/126] Maria Boss -> 3 entries
# [10/126] Fernanda Bravo -> 8 entries
# [11/126] Felipe Caro -> no entries (matched headers=[])
# [12/126] Heather Maiirhe Caruso -> 5 entries
# [13/126] Eugene M. Caruso -> 50 entries
# [14/126] Francisco Castro -> 8 entries
# [15/126] M. Keith Chen -> 9 entries
# [16/126] Mikhail Chernov -> 7 entries
# [17/126] Hanne Collins -> no entries (matched headers=[])
# [18/126] Charles Corbett -> 29 entries
# [19/126] Samuel Culbert -> 5 entries
# [20/126] Hengchen Dai -> 10 entries
# [21/126] Magali (Maggie) Delmas -> 57 entries
# [22/126] David DeVito -> no entries (matched headers=[])
# [23/126] Sanford E. DeVoe -> 25 entries
# [24/126] Aimee Drolet Rossi -> 31 entries
# [25/126] Sebastian Edwards -> 104 entries
# [26/126] Andrea Eisfeldt -> no entries (matched headers=[])
# [27/126] Constança Esteves-Sorenson -> 4 entries
# [28/126] Brian Farrell -> no entries (matched headers=[])
# [29/126] Iris Firstenberg -> 6 entries
# [30/126] Craig Fox -> 50 entries
# [31/126] Gonzalo Freixes -> no entries (matched headers=[])
# [32/126] Henry Friedman -> no entries (matched headers=['Publications', 'Working Papers'])
# [33/126] Stuart A. Gabriel -> 36 entries
# [34/126] Jana Gallus -> 13 entries
# [35/126] Ashvin Gandhi -> 18 entries
# [36/126] Julie Ann Gardner -> no entries (matched headers=[])
# [37/126] Mark J. Garmaise -> 6 entries
# [38/126] Paola Giuliano -> no entries (matched headers=['Working Papers'])
# [39/126] Noah Goldstein -> 21 entries
# [40/126] Stephen Greene -> no entries (matched headers=[])
# [41/126] Jane Guerin -> no entries (matched headers=[])
# [42/126] Paul Habibi -> no entries (matched headers=[])
# [43/126] Valentin Haddad -> 1 entries
# [44/126] Kareem Haggag -> no entries (matched headers=[])
# [45/126] Barney Hartman-Glaser -> no entries (matched headers=['Publications'])
# [46/126] Carla Hayn -> 6 entries
# [47/126] Joyce C. He -> no entries (matched headers=[])
# [48/126] Hal Hershfield -> 32 entries
# [49/126] Bernard Herskovic -> 1 entries
# [50/126] Brett Hollenbeck -> 12 entries
# [51/126] Elisabeth Honka -> 19 entries
# [52/126] Jason Hsu -> 27 entries
# [53/126] Erica Xuewei Jiang -> 12 entries
# [54/126] Matthias Kahl -> 5 entries
# [55/126] Jennifer Kao -> no entries (matched headers=['Publications'])
# [56/126] Mark S. Karlan -> no entries (matched headers=[])
# [57/126] Mark Kim -> no entries (matched headers=['Working Papers'])
# [58/126] Gordon Klein -> no entries (matched headers=[])
# [59/126] Terry Kramer -> no entries (matched headers=[])
# [60/126] Shohini Kundu -> no entries (matched headers=['Working Papers'])
# [61/126] H. Tai Lam -> no entries (matched headers=[])
# [62/126] Ian Larkin -> no entries (matched headers=['Publications'])
# [63/126] Jason Lee -> no entries (matched headers=[])
# [64/126] Alicea Lieberman -> no entries (matched headers=[])
# [65/126] Marvin Lieberman -> 41 entries
# [66/126] Lars Augestad Lochstoer -> 15 entries
# [67/126] Elisa Long -> 17 entries
# [68/126] Francis Longstaff -> 74 entries
# [69/126] Ming Lu -> no entries (matched headers=[])
# [70/126] Jennifer McCaney -> no entries (matched headers=[])
# [71/126] Robert M. McCann -> no entries (matched headers=[])
# [72/126] Beatrice Michaeli -> no entries (matched headers=['Publications', 'Working Papers and Works in Progress'])
# [73/126] Dylan Minor -> no entries (matched headers=[])
# [74/126] Velibor Mišić -> 3 entries
# [75/126] Cassie Mogilner Holmes -> 30 entries
# [76/126] Jeff Moorad -> no entries (matched headers=[])
# [77/126] Dinesh Moorjani -> no entries (matched headers=['Working Papers'])
# [78/126] Tyler Muir -> 11 entries
# [79/126] Daniel A. Nathanson -> no entries (matched headers=[])
# [80/126] M. Kathleen Ngangoué -> no entries (matched headers=[])
# [81/126] Gayle Northrop -> no entries (matched headers=[])
# [82/126] Stavros Panageas -> 25 entries
# [83/126] Ricardo Perez-Truglia -> no entries (matched headers=[])
# [84/126] Christopher Poliquin -> 2 entries
# [85/126] Kumar Rajaram -> 38 entries
# [86/126] David Ravetch -> no entries (matched headers=[])
# [87/126] Eric Reiner -> no entries (matched headers=[])
# [88/126] Scott Rodilitz -> no entries (matched headers=[])
# [89/126] Peter Rossi -> no entries (matched headers=['Working Papers and Technical Reports'])
# [90/126] Mariko Sakakibara -> 28 entries
# [91/126] Lori Santikian -> no entries (matched headers=[])
# [92/126] Sarada -> no entries (matched headers=[])
# [93/126] Rakesh Sarin -> 12 entries
# [94/126] Gregor Schubert -> no entries (matched headers=[])
# [95/126] Franklin Shaddy -> 16 entries
# [96/126] Terrence Shi -> no entries (matched headers=[])
# [97/126] Margaret Shih -> 20 entries
# [98/126] Auyon Siddiq -> 8 entries
# [99/126] Sanjay Sood -> 19 entries
# [100/126] Olav Sorenson -> 11 entries
# [101/126] Stephen Spiller -> no entries (matched headers=[])
# [102/126] Avanidhar (Subra) Subrahmanyam -> 13 entries
# [103/126] Kati Suominen -> no entries (matched headers=[])
# [104/126] Eric Sussman -> no entries (matched headers=[])
# [105/126] Siew Hong Teoh -> no entries (matched headers=[])
# [106/126] Andres Terech -> 9 entries
# [107/126] Omid Toloui -> no entries (matched headers=[])
# [108/126] Clemence Tricaud -> 1 entries
# [109/126] John Ullmen -> no entries (matched headers=[])
# [110/126] Miguel M. Unzueta -> 8 entries
# [111/126] John Villasenor -> no entries (matched headers=[])
# [112/126] Nico Voigtländer -> 12 entries
# [113/126] Romain Wacziarg -> 15 entries
# [114/126] Melanie Wasserman -> 8 entries
# [115/126] Ivo Welch -> no entries (matched headers=['Published Papers'])
# [116/126] David Wessels -> no entries (matched headers=[])
# [117/126] Brian Wheaton -> 11 entries
# [118/126] Jennifer Whitson -> 21 entries
# [119/126] Nathan Wilson -> no entries (matched headers=[])
# [120/126] Jane Wu -> no entries (matched headers=[])
# [121/126] Sherry Jueyu Wu -> no entries (matched headers=[])
# [122/126] Wesley Yin -> 23 entries
# [123/126] Yihao Yuan -> no entries (matched headers=[])
# [124/126] Robert Zeithammer -> no entries (matched headers=[])
# [125/126] Jinyuan Zhang -> 4 entries
# [126/126] Shi(shir) Zhang -> 4 entries
#
# Saved: ucla_anderson_pubs_papers_only.csv (rows=1179)

# %%
import pandas as pd

df = pd.read_csv("ucla_anderson_pubs_papers_only.csv")  # 改成你的实际文件名
df.head(20)
# Out:
#                   name                                       profile_link  \
# 0    Corinne Bendersky  https://www.anderson.ucla.edu/faculty-and-rese...
# 1    Corinne Bendersky  https://www.anderson.ucla.edu/faculty-and-rese...
# 2    Corinne Bendersky  https://www.anderson.ucla.edu/faculty-and-rese...
# 3    Corinne Bendersky  https://www.anderson.ucla.edu/faculty-and-rese...
# 4    Corinne Bendersky  https://www.anderson.ucla.edu/faculty-and-rese...
# 5    Corinne Bendersky  https://www.anderson.ucla.edu/faculty-and-rese...
# 6    Corinne Bendersky  https://www.anderson.ucla.edu/faculty-and-rese...
# 7    Corinne Bendersky  https://www.anderson.ucla.edu/faculty-and-rese...
# 8    Corinne Bendersky  https://www.anderson.ucla.edu/faculty-and-rese...
# 9    Corinne Bendersky  https://www.anderson.ucla.edu/faculty-and-rese...
# 10   Corinne Bendersky  https://www.anderson.ucla.edu/faculty-and-rese...
# 11   Corinne Bendersky  https://www.anderson.ucla.edu/faculty-and-rese...
# 12   Corinne Bendersky  https://www.anderson.ucla.edu/faculty-and-rese...
# 13   Corinne Bendersky  https://www.anderson.ucla.edu/faculty-and-rese...
# 14   Corinne Bendersky  https://www.anderson.ucla.edu/faculty-and-rese...
# 15   Corinne Bendersky  https://www.anderson.ucla.edu/faculty-and-rese...
# 16  Daniel J. Benjamin  https://www.anderson.ucla.edu/faculty-and-rese...
# 17  Daniel J. Benjamin  https://www.anderson.ucla.edu/faculty-and-rese...
# 18  Daniel J. Benjamin  https://www.anderson.ucla.edu/faculty-and-rese...
# 19  Daniel J. Benjamin  https://www.anderson.ucla.edu/faculty-and-rese...
#
#                                                 entry    year
# 0   Pai, J. & Bendersky, C. (2020) “ Team Status C...  2020.0
# 1   Danbold, F. & Bendersky, C. (2020) “ Balancing...  2020.0
# 2   Bendersky, C. and Pai, J. (2018). “Status Dyna...  2018.0
# 3   Bendersky, C. (2018). “ Making U.S. Fire Depar...  2018.0
# 4   Bendersky, C., & Hays, N. A. 2017. The Positiv...  2017.0
# 5   Tsai, M., and Bendersky, C. (2016) “The pursui...  2016.0
# 6   Hays, N. A., & Bendersky, C. (2015). Not at al...  2015.0
# 7   Weingart, L., Behfar, K., Bendersky, C., Todor...  2015.0
# 8   Bendersky, C. (2014). Resolving Ideological Co...  2014.0
# 9   Bendersky, C. and Shah, N. (2013). The downfal...  2013.0
# 10  Bendersky, C. and Shah, N. (2012). The cost of...  2012.0
# 11  Bendersky, C. and Hays, N. (2012). Status conf...  2012.0
# 12  Long, C., Bendersky, C. and Morrill, C. (2011)...  2011.0
# 13  Bendersky, C. and Curhan, J. (2009). Dissonanc...  2009.0
# 14  Bendersky, C. (2003). Organizational Dispute R...  2003.0
# 15  Jehn, K. A. and Bendersky, C. (2003). Intragro...  2003.0
# 16  Benjamin, Daniel J., David I. Laibson, Walter ...     NaN
# 17  Benjamin, Daniel J., and James O. Berger (2019...  2019.0
# 18  Benjamin, Daniel J., James O. Berger, Magnus J...  2018.0
# 19  Benjamin, Daniel J., James J. Choi, and Geoffr...  2016.0
